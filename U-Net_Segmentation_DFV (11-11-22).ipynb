# %% [markdown]
# # U-Net Arquitectura Básica
#
# (https://www.kaggle.com/c/data-science-bowl-2018/data)
#
# (https://arxiv.org/pdf/1505.04597.pdf)

# %% [markdown]
# ##<b> Importación de librerías necesarias: </b>

# %%
import os
import numpy as np
from tqdm import tqdm 
from skimage.io import imread, imshow
from skimage.transform import resize
import matplotlib.pyplot as plt
import datetime

import pandas as pd
import cv2
import glob
import random
import shutil

# Librerias para constuir la arquitectura U-Net
from tensorflow.keras.layers import Input, Lambda, Conv2D, Dropout, MaxPooling2D, Conv2DTranspose, concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ##<b> Montaje de unidad Google Drive en el entorno de ejecución: </b>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/Implementación Proyecto Grado Maestría
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Implementación Proyecto Grado Maestría

# %% [markdown]
# ##<b> Verificación presencia de GPU: </b>

# %%
# %tensorflow_version 2.x
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.
# Found GPU at: /device:GPU:0

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Fri Nov 11 08:36:56 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   54C    P0    26W /  70W |    312MiB / 15109MiB |      1%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ##<b> Carga de dataframe descriptivo del mini-MIAS dataset: </b>

# %%
dataPath = "all-mias"
textFile = os.path.join(dataPath,"miasInfo.txt")
mias_df = pd.read_csv(textFile, sep=" ", header=0)
mias_df.head()

#OJO: metadatos de Kaggle están mal. Marcan la mdb212 como anormal (mdb212 G CALC B 687 882 3) y es normal. Puede haber otras mal etiquetadas. OJO
#Usaré los metadatos de: http://peipa.essex.ac.uk/info/mias.html
# Out:
#    REFNUM BG CLASS SEVERITY      X      Y  RADIUS
# 0  mdb001  G  CIRC        B  535.0  425.0   197.0
# 1  mdb002  G  CIRC        B  522.0  280.0    69.0
# 2  mdb003  D  NORM      NaN    NaN    NaN     NaN
# 3  mdb004  D  NORM      NaN    NaN    NaN     NaN
# 4  mdb005  F  CIRC        B  477.0  133.0    30.0

# %%
values = {"SEVERITY": 'N', "X": 0, "Y": 0, "RADIUS": 0}
mias_df = mias_df.fillna(value=values)
mias_df.head()
# Out:
#    REFNUM BG CLASS SEVERITY      X      Y  RADIUS
# 0  mdb001  G  CIRC        B  535.0  425.0   197.0
# 1  mdb002  G  CIRC        B  522.0  280.0    69.0
# 2  mdb003  D  NORM        N    0.0    0.0     0.0
# 3  mdb004  D  NORM        N    0.0    0.0     0.0
# 4  mdb005  F  CIRC        B  477.0  133.0    30.0

# %%
mias_df.X = mias_df.X.astype(int)
mias_df.Y = mias_df.Y.astype(int)
mias_df.RADIUS = mias_df.RADIUS.astype(int)
mias_df.head()
# Out:
#    REFNUM BG CLASS SEVERITY    X    Y  RADIUS
# 0  mdb001  G  CIRC        B  535  425     197
# 1  mdb002  G  CIRC        B  522  280      69
# 2  mdb003  D  NORM        N    0    0       0
# 3  mdb004  D  NORM        N    0    0       0
# 4  mdb005  F  CIRC        B  477  133      30

# %%
#Split by class:
benignClass = mias_df[mias_df.SEVERITY=='B']
print("benignClass before balance shape: ", benignClass.shape)

malignantClass = mias_df[mias_df.SEVERITY=='M']
print("malignantClass before balance shape: ", malignantClass.shape)

normalClass = mias_df[mias_df.SEVERITY=='N']
print("normalClass before balance shape: ", normalClass.shape)
# Out:
# benignClass before balance shape:  (67, 7)
# malignantClass before balance shape:  (54, 7)
# normalClass before balance shape:  (209, 7)

# %%
mias_df_2 = pd.concat([benignClass, malignantClass, normalClass]) 

#Split features and labels:
#Label = mias_df_2.SEVERITY
#Features = mias_df_2.drop(['SEVERITY', 'REFNUM'],axis=1)
#feature_columns = Features.columns

#display("mias_df_2:", mias_df_2.head())
#display("Features:", Features.head())
#display("Label:", Label.head())
print(mias_df_2)
# Out:
#      REFNUM BG CLASS SEVERITY    X    Y  RADIUS
# 0    mdb001  G  CIRC        B  535  425     197
# 1    mdb002  G  CIRC        B  522  280      69
# 4    mdb005  F  CIRC        B  477  133      30
# 5    mdb005  F  CIRC        B  500  168      26
# 10   mdb010  F  CIRC        B  525  425      33
# ..      ... ..   ...      ...  ...  ...     ...
# 325  mdb318  D  NORM        N    0    0       0
# 326  mdb319  D  NORM        N    0    0       0
# 327  mdb320  D  NORM        N    0    0       0
# 328  mdb321  D  NORM        N    0    0       0
# 329  mdb322  D  NORM        N    0    0       0
#
# [330 rows x 7 columns]

# %% [markdown]
# Detecto las imágenes que son anormales y no están etiquetadas y creo un nuevo dataframe (mias_df_new) sin ellas. También copio todas excepto esas a una nueva carpeta (all-miasPyProc-new). Son 4.

# %%
imgs_to_drop_df = mias_df_2[(mias_df_2['SEVERITY'] != 'N') & (mias_df_2['RADIUS'] == 0)]
imgs_to_drop = (imgs_to_drop_df.REFNUM).tolist()
print('imgs_to_drop: ' + str(imgs_to_drop) + '\n')
mias_df_new = mias_df_2.drop(mias_df_2[(mias_df_2['SEVERITY'] != 'N') & (mias_df_2['RADIUS'] == 0)].index)
print(mias_df_new)
#print(mias_df_new.loc[[214]])
# Out:
# imgs_to_drop: ['mdb059', 'mdb216', 'mdb233', 'mdb245']
#
#      REFNUM BG CLASS SEVERITY    X    Y  RADIUS
# 0    mdb001  G  CIRC        B  535  425     197
# 1    mdb002  G  CIRC        B  522  280      69
# 4    mdb005  F  CIRC        B  477  133      30
# 5    mdb005  F  CIRC        B  500  168      26
# 10   mdb010  F  CIRC        B  525  425      33
# ..      ... ..   ...      ...  ...  ...     ...
# 325  mdb318  D  NORM        N    0    0       0
# 326  mdb319  D  NORM        N    0    0       0
# 327  mdb320  D  NORM        N    0    0       0
# 328  mdb321  D  NORM        N    0    0       0
# 329  mdb322  D  NORM        N    0    0       0
#
# [326 rows x 7 columns]

# %%
#files = glob.glob(dataPath+'/all-miasPythonProcessed/*.png')
#files = glob.glob(dataPath+'/all-mias_mat_proc_eq/*.png')
files = glob.glob(dataPath+'/01_allmias_mat_proc_eq/*.png')


if os.path.isdir(dataPath+'/all-miasPyProc-new') is False:
  os.mkdir(dataPath+'/all-miasPyProc-new')
  for myFile in files:
      basename = os.path.basename(myFile)  # e.g. MyPhoto.jpg
      name = os.path.splitext(basename)[0]  # e.g. MyPhoto
      name = name[:6]
      if (name not in imgs_to_drop):
        shutil.copy(myFile, dataPath+'/all-miasPyProc-new/'+name+'_proc.png')

# %% [markdown]
# ##<b> Creación de máscara para una imagen: </b>
# Se tendrá en cuenta que puede haber más de una anormalidad por imagen

# %%
image_path = dataPath+'/allmias_PNG_mat_eq/mdb239_output.png'

image = cv2.imread(image_path,0) #flag = 0 = cv2.IMREAD_GRAYSCALE
image_name = image_path[28:34]
print(image_name)
fig, ax = plt.subplots(figsize=(5,5))

ax.imshow(image, cmap='gray', vmin=0, vmax=255)
ax.set_title("roi_marked_image "+image_name)
ax.axis('off')

plt.tight_layout()
plt.show()

roi_df = mias_df_new.loc[mias_df_new['REFNUM'] == image_name, ['X', 'Y', 'RADIUS']]
#print(roi_df)
roi_values = roi_df.values
height, width = image.shape[:2] #height, width, without number of channels in image

selected_image_df = mias_df_new.loc[mias_df_new['REFNUM'] == image_name]
selected_image_df.head()
# Out:
# mdb239
#      REFNUM BG CLASS SEVERITY    X    Y  RADIUS
# 244  mdb239  D  CALC        M  645  755      40
# 245  mdb239  D  CALC        M  567  808      25

# %%
color = 0
thickness = 2 # Line thickness of 2 px

for row in roi_values:
    X, Y, RADIUS = row
    Y_new = height - Y
    cv2.circle(image, (X,Y_new), RADIUS, color, thickness)

fig, ax = plt.subplots(figsize=(5,5))

ax.imshow(image, cmap='gray', vmin=0, vmax=255)
ax.set_title("roi_marked_image "+image_name)
ax.axis('off')

plt.tight_layout()
plt.show()

# %%
color = 255
zeros_image = np.zeros(image.shape[:2], np.uint8)

for row in roi_values:
    X, Y, RADIUS = row
    Y_new = height - Y
    mask = cv2.circle(zeros_image, (X,Y_new), RADIUS, color, cv2.FILLED)
    #mask = cv2.circle(ones_image, (X,Y_new), RADIUS, color, cv2.FILLED)

fig, ax = plt.subplots(figsize=(5,5))

ax.imshow(mask, cmap='gray', vmin=0, vmax=255)
ax.set_title("mask for "+image_name)
ax.axis('off')

plt.tight_layout()
plt.show()

# %%
masked_image = cv2.bitwise_and(image,mask)
fig, ax = plt.subplots(figsize=(6,6))
ax.imshow(masked_image, cmap='gray', vmin=0, vmax=255)
ax.set_title("mask for "+image_name)
ax.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##<b> Creación de máscaras para todas las mamografías que presenten anormalidades: </b>
#
# Por cada imagen crear una carpeta con dos subcarpetas:
#
# Una carpeta "images" (será all-miasPythonProcessed) con la imagen
#
# Una carpeta "masks" con la máscara o las máscaras binarias
#
# Otra carpeta test con una subcarpeta images dentro la imagen de prueba
#
# Carpeta 	mdb001
#
# Subcarpetas 	images     : mdb001_processed
#               masks      : mdb001_processed_mask

# %%
abnormal_imgs_path = (dataPath+'/U-Net_images_masks/train/images/abnormal/')
normal_imgs_path = (dataPath+'/U-Net_images_masks/train/images/normal/')

abnormal_msks_path = (dataPath+'/U-Net_images_masks/train/masks/abnormal/')
normal_msks_path = (dataPath+'/U-Net_images_masks/train/masks/normal/')

if os.path.isdir(abnormal_imgs_path) is False:
  os.makedirs(abnormal_imgs_path)
  os.makedirs(normal_imgs_path)
  os.makedirs(abnormal_msks_path)
  os.makedirs(normal_msks_path)

  abnorm_imgs = []
  abnorm_masks = []
  abnorm_names = []
  norm_imgs = []
  norm_masks = []
  norm_names = []
  
  #files = glob.glob(dataPath+'/allmias_PNG_mat_eq/*.png')
  files = glob.glob(dataPath+'/all-miasPyProc-new/*.png')
  print('se crearon las carpetas y file es all-mias py proc new')

  color = 255

  for file_path in files:
      #print(myFile)
      image = cv2.imread(file_path,0)
      #image_name = file_path[28:34]
      basename = os.path.basename(file_path)  # e.g. MyPhoto.jpg
      name = os.path.splitext(basename)[0]  # e.g. MyPhoto
      roi_df = mias_df_new.loc[mias_df_new['REFNUM'] == name[:6], ['X', 'Y', 'RADIUS']]
      roi_values = roi_df.values
      height, width = image.shape[:2] #height, width, without number of channels
      zeros_image = np.zeros(image.shape[:2], np.uint8) 
      for row in roi_values:
          X, Y, RADIUS = row
          Y_new = height - Y
          mask = cv2.circle(zeros_image, (X,Y_new), RADIUS, color, cv2.FILLED)
      result = np.all(mask == mask[0])
      if result:
          norm_imgs.append(image)  #print('Los valores son iguales, la máscara es de img normal, no se añade al arreglo') 
          norm_masks.append(mask)
          norm_names.append(name)#image_name+'_proc')
      else:
          abnorm_imgs.append(image)
          abnorm_masks.append(mask)
          abnorm_names.append(name)#image_name+'_proc')

  #print(len(abnorm_imgs))
  print(abnorm_names)
  #print(len(abnorm_names))
  #print(len(norm_imgs))
  #print(len(norm_names))

  for abnorm_name, abnorm_image, abnorm_mask in zip(abnorm_names, abnorm_imgs, abnorm_masks):
      cv2.imwrite((dataPath+'/U-Net_images_masks/train/images/abnormal/' + abnorm_name + '.png'), abnorm_image) 
      cv2.imwrite((dataPath+'/U-Net_images_masks/train/masks/abnormal/' + abnorm_name + '_mask.png'), abnorm_mask)

  for norm_name, norm_image, norm_mask in zip(norm_names, norm_imgs, norm_masks):
      cv2.imwrite((dataPath+'/U-Net_images_masks/train/images/normal/' + norm_name + '.png'), norm_image)
      cv2.imwrite((dataPath+'/U-Net_images_masks/train/masks/normal/' + norm_name + '_mask.png'), norm_mask)
# Out:
# se crearon las carpetas y file es all-mias py proc new
# ['mdb102_proc', 'mdb104_proc', 'mdb105_proc', 'mdb107_proc', 'mdb010_proc', 'mdb110_proc', 'mdb111_proc', 'mdb115_proc', 'mdb117_proc', 'mdb120_proc', 'mdb121_proc', 'mdb124_proc', 'mdb125_proc', 'mdb126_proc', 'mdb127_proc', 'mdb012_proc', 'mdb130_proc', 'mdb132_proc', 'mdb134_proc', 'mdb013_proc', 'mdb141_proc', 'mdb142_proc', 'mdb144_proc', 'mdb145_proc', 'mdb148_proc', 'mdb150_proc', 'mdb152_proc', 'mdb155_proc', 'mdb158_proc', 'mdb015_proc', 'mdb160_proc', 'mdb163_proc', 'mdb165_proc', 'mdb167_proc', 'mdb170_proc', 'mdb171_proc', 'mdb175_proc', 'mdb178_proc', 'mdb179_proc', 'mdb017_proc', 'mdb181_proc', 'mdb184_proc', 'mdb186_proc', 'mdb188_proc', 'mdb190_proc', 'mdb191_proc', 'mdb193_proc', 'mdb195_proc', 'mdb198_proc', 'mdb199_proc', 'mdb019_proc', 'mdb001_proc', 'mdb202_proc', 'mdb204_proc', 'mdb206_proc', 'mdb207_proc', 'mdb209_proc', 'mdb211_proc', 'mdb213_proc', 'mdb218_proc', 'mdb219_proc', 'mdb021_proc', 'mdb222_proc', 'mdb223_proc', 'mdb226_proc', 'mdb227_proc', 'mdb231_proc', 'mdb236_proc', 'mdb238_proc', 'mdb239_proc', 'mdb023_proc', 'mdb240_proc', 'mdb241_proc', 'mdb244_proc', 'mdb248_proc', 'mdb249_proc', 'mdb252_proc', 'mdb253_proc', 'mdb256_proc', 'mdb025_proc', 'mdb264_proc', 'mdb265_proc', 'mdb267_proc', 'mdb270_proc', 'mdb271_proc', 'mdb274_proc', 'mdb028_proc', 'mdb290_proc', 'mdb002_proc', 'mdb030_proc', 'mdb312_proc', 'mdb314_proc', 'mdb315_proc', 'mdb032_proc', 'mdb058_proc', 'mdb005_proc', 'mdb063_proc', 'mdb069_proc', 'mdb072_proc', 'mdb075_proc', 'mdb080_proc', 'mdb081_proc', 'mdb083_proc', 'mdb090_proc', 'mdb091_proc', 'mdb092_proc', 'mdb095_proc', 'mdb097_proc', 'mdb099_proc']

# %% [markdown]
# ## Separación imágenes para test
# En una sola carpeta llamada test (30% de las imágenes), antes de hacerle augmentation para evitar overfitting.
#
# Teniendo en cuenta que en total, después de todo lo anterior hay:
#
# 109 imágenes anormales en train -> 33 se pasan a test -> Quedan 76 en train.
#
# 209 imágenes normales en train -> 63 se pasan a test -> Quedan 146 en train.

# %%
#Aquí tengo que escribir las instrucciones para mover el 30% de train abnorm_imgs y train abnorm_masks a test abnorn_imgs y test abnorm_masks:

if os.path.isdir(dataPath+'/U-Net_images_masks/test/images/abnormal/') is False:
  os.makedirs(dataPath+'/U-Net_images_masks/test/images/abnormal/')
  os.makedirs(dataPath+'/U-Net_images_masks/test/masks/abnormal/')
  os.makedirs(dataPath+'/U-Net_images_masks/test/images/normal/')
  os.makedirs(dataPath+'/U-Net_images_masks/test/masks/normal/')

  train_abnorm_imgs = glob.glob(dataPath+'/U-Net_images_masks/train/images/abnormal/*.png')
  train_norm_imgs = glob.glob(dataPath+'/U-Net_images_masks/train/images/normal/*.png')

  #train_images = glob.glob(images_train_path+'*')
  #train_masks = glob.glob(masks_train_path+'*') 
  test_abnorm_imgs = random.sample(train_abnorm_imgs, 33) #aprox. 30% de las imágenes para test. De ahí se saca para valid y test (se puede probar con 20% (10% y 10%))
  test_norm_imgs = random.sample(train_norm_imgs, 63)
  test_abnorm_msks=[]
  test_norm_msks=[]

  for test_abnorm_img in test_abnorm_imgs:
      index_ab = test_abnorm_img.find('proc')
      index_ab_2 = test_abnorm_img.find('images/') 
      test_abnorm_msk = test_abnorm_img[:index_ab+4] + '_mask' + test_abnorm_img[index_ab+4:] 
      test_abnorm_msk_2 = test_abnorm_msk[:index_ab_2] + 'masks/' + test_abnorm_msk[index_ab_2+7:]
      test_abnorm_msks.append(test_abnorm_msk_2) 
  
  for test_norm_img in test_norm_imgs:
      index_n = test_norm_img.find('proc')
      index_n_2 = test_norm_img.find('images/') 
      test_norm_msk = test_norm_img[:index_n+4] + '_mask' + test_norm_img[index_n+4:] 
      test_norm_msk_2 = test_norm_msk[:index_n_2] + 'masks/' + test_norm_msk[index_n_2+7:]
      test_norm_msks.append(test_norm_msk_2) 

  print(test_abnorm_imgs)
  print(test_abnorm_msks)
  print(test_norm_imgs)
  print(test_norm_msks) 

  for test_image, test_mask in zip(test_abnorm_imgs, test_abnorm_msks):
      shutil.move(test_image, dataPath+'/U-Net_images_masks/test/images/abnormal')   
      shutil.move(test_mask, dataPath+'/U-Net_images_masks/test/masks/abnormal') 

  for test_image, test_mask in zip(test_norm_imgs, test_norm_msks):
      shutil.move(test_image, dataPath+'/U-Net_images_masks/test/images/normal')   
      shutil.move(test_mask, dataPath+'/U-Net_images_masks/test/masks/normal')
# Out:
# ['all-mias/U-Net_images_masks/train/images/abnormal/mdb095_proc.png', 'all-mias/U-Net_images_masks/train/images/abnormal/mdb198_proc.png', 'all-mias/U-Net_images_masks/train/images/abnormal/mdb005_proc.png', 'all-mias/U-Net_images_masks/train/images/abnormal/mdb013_proc.png', 'all-mias/U-Net_images_masks/train/images/abnormal/mdb127_proc.png', 'all-mias/U-Net_images_masks/train/images/abnormal/mdb021_proc.png', 'all-mias/U-Net_images_masks/train/images/abnormal/mdb171_proc.png', 'all-mias/U-Net_images_masks/train/images/abnormal/mdb083_proc.png', 'all-mias/U-Net_images_masks/train/images/abnormal/mdb181_proc.png', 'all-mias/U-Net_images_masks/train/images/abnormal/mdb178_proc.png', 'all-mias/U-Net_images_masks/train/images/abnormal/mdb141_proc.png', 'all-mias/U-Net_images_masks/train/images/abnormal/mdb207_proc.png', 'all-mias/U-Net_images_masks/train/images/abnormal/mdb105_proc.png', 'all-mias/U-Net_images_masks/train/images/abnormal/mdb191_proc.png', 'all-mias/U-Net_images_masks/train/images/abnormal/mdb315_proc.png', 'all-mias/U-Net_images_masks/train/images/abnormal/mdb111_proc.png', 'all-mias/U-Net_images_masks/train/images/abnormal/mdb145_proc.png', 'all-mias/U-Net_images_masks/train/images/abnormal/mdb236_proc.png', 'all-mias/U-Net_images_masks/train/images/abnormal/mdb163_proc.png', 'all-mias/U-Net_images_masks/train/images/abnormal/mdb248_proc.png', 'all-mias/U-Net_images_masks/train/images/abnormal/mdb167_proc.png', 'all-mias/U-Net_images_masks/train/images/abnormal/mdb104_proc.png', 'all-mias/U-Net_images_masks/train/images/abnormal/mdb001_proc.png', 'all-mias/U-Net_images_masks/train/images/abnormal/mdb314_proc.png', 'all-mias/U-Net_images_masks/train/images/abnormal/mdb238_proc.png', 'all-mias/U-Net_images_masks/train/images/abnormal/mdb010_proc.png', 'all-mias/U-Net_images_masks/train/images/abnormal/mdb188_proc.png', 'all-mias/U-Net_images_masks/train/images/abnormal/mdb090_proc.png', 'all-mias/U-Net_images_masks/train/images/abnormal/mdb019_proc.png', 'all-mias/U-Net_images_masks/train/images/abnormal/mdb017_proc.png', 'all-mias/U-Net_images_masks/train/images/abnormal/mdb069_proc.png', 'all-mias/U-Net_images_masks/train/images/abnormal/mdb219_proc.png', 'all-mias/U-Net_images_masks/train/images/abnormal/mdb134_proc.png']
# ['all-mias/U-Net_images_masks/train/masks/abnormal/mdb095_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/abnormal/mdb198_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/abnormal/mdb005_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/abnormal/mdb013_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/abnormal/mdb127_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/abnormal/mdb021_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/abnormal/mdb171_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/abnormal/mdb083_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/abnormal/mdb181_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/abnormal/mdb178_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/abnormal/mdb141_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/abnormal/mdb207_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/abnormal/mdb105_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/abnormal/mdb191_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/abnormal/mdb315_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/abnormal/mdb111_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/abnormal/mdb145_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/abnormal/mdb236_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/abnormal/mdb163_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/abnormal/mdb248_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/abnormal/mdb167_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/abnormal/mdb104_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/abnormal/mdb001_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/abnormal/mdb314_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/abnormal/mdb238_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/abnormal/mdb010_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/abnormal/mdb188_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/abnormal/mdb090_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/abnormal/mdb019_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/abnormal/mdb017_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/abnormal/mdb069_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/abnormal/mdb219_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/abnormal/mdb134_proc_mask.png']
# ['all-mias/U-Net_images_masks/train/images/normal/mdb303_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb301_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb292_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb093_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb112_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb220_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb101_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb174_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb259_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb254_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb176_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb140_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb034_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb056_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb084_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb018_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb164_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb087_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb305_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb100_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb143_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb228_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb281_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb085_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb052_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb057_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb139_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb011_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb172_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb039_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb094_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb066_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb106_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb295_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb020_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb197_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb067_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb221_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb321_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb098_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb079_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb038_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb242_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb031_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb008_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb282_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb196_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb173_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb177_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb255_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb263_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb053_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb146_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb159_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb009_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb212_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb269_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb208_proc.png', 'all-mias/U-Net_images_masks/train/images/normal/mdb076_proc.png', 'all-mias/U-Net_images_masks/train/images/norm ...
# ['all-mias/U-Net_images_masks/train/masks/normal/mdb303_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb301_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb292_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb093_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb112_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb220_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb101_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb174_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb259_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb254_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb176_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb140_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb034_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb056_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb084_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb018_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb164_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb087_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb305_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb100_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb143_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb228_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb281_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb085_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb052_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb057_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb139_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb011_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb172_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb039_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb094_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb066_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb106_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb295_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb020_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb197_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb067_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb221_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb321_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb098_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb079_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb038_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb242_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb031_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb008_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb282_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb196_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb173_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb177_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb255_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb263_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb053_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb146_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb159_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb009_proc_mask.png', 'all-mias/U-Net_images_masks/train/masks/normal/mdb212_proc_mask.png', 'all-mias/U-Net_images_ ...

# %% [markdown]
# ## Data Augmentation:

# %% [markdown]
# Función para generar y guardar el aumento de imágenes:

# %%
def augmentImages(images_paths, dir, imgs_per_image, pixel_fill):
  #images_paths = glob.glob(images_path+'/*.png')

  #Trataré de meter las imágenes a un arreglo para que sean leídas más rápido cuando haga el augmentation:
  imgs_arr=[]
  imgs_names_arr=[]
  for myFile in images_paths:
    image = cv2.imread(myFile)
    imgs_arr.append(image)
    basename = os.path.basename(myFile)  # e.g. MyPhoto.jpg
    name = os.path.splitext(basename)[0]  # e.g. MyPhoto  
    imgs_names_arr.append(name) 

  for myImage, myName in zip(imgs_arr, imgs_names_arr):
    image = np.expand_dims(myImage,0)
    #min_pixel = np.min(image)
    #min_pixel = 239 #np.max(image) 
    #gen = ImageDataGenerator(rotation_range=10, width_shift_range=0.15, height_shift_range=0.15, fill_mode='constant',
    #                          cval=pixel_fill, shear_range=0.15, zoom_range=0.15, horizontal_flip=True)# brightness_range=[0.6,1.3])

    gen = ImageDataGenerator(rotation_range=12, width_shift_range=0.15, height_shift_range=0.15, fill_mode='constant',
                              cval=pixel_fill, shear_range=0.15, horizontal_flip=True)# brightness_range=[0.6,1.3])
    #gen = ImageDataGenerator(width_shift_range=0.15, height_shift_range=0.15, fill_mode='constant',
    #                          cval=min_pixel, shear_range=0.15, zoom_range=0.15, horizontal_flip=True)

    #Save augmented images
    aug_iter = gen.flow(image, save_to_dir=dir, save_prefix='aug_'+myName, save_format='png', seed=1)
    aug_images = [next(aug_iter)[0].astype(np.uint8) for i in range(imgs_per_image)]

# %% [markdown]
# Lo hago para las anormales, que son menos. Para las de train y las de test:

# %%
#min_pixel = np.min(image)
#max_pixel_img = 239 #np.max(image) 
min_pixel_img = 16
min_pixel_msk = 0 

#Abnormales para train:

images_train_path = dataPath+'/U-Net_images_masks/train/images/abnormal/'
if len(os.listdir(images_train_path)) == 76:
  train_images_paths = glob.glob(images_train_path+'*.png')
  augmentImages(train_images_paths, images_train_path, 3, min_pixel_img) # actualizar estos números: (x3 aug) Si fueran 4: 78 x 4 = 312, tocaría por 3 porque la 4ta sería la original. Porque 312/2 = 156, si normal = 145 es aprox. 1/3 del total

masks_train_path = dataPath+'/U-Net_images_masks/train/masks/abnormal/'
if len(os.listdir(masks_train_path)) == 76:
  train_masks_paths = glob.glob(masks_train_path+'*.png')
  augmentImages(train_masks_paths, masks_train_path, 3, min_pixel_msk) 


#Abnormales para test:

#images_test_path = dataPath+'/U-Net_images_masks/test/images/abnormal/'
#if len(os.listdir(images_test_path)) == 33:
#  test_images_paths = glob.glob(images_test_path+'*.png')
#  augmentImages(test_images_paths, images_test_path, 3, min_pixel_img) #(x3 aug) Si fueran 4: 33 x 4 = 132, tocaría por 3 porque la 4ta sería la original. Porque 132/2 = 66, si normal = 62 es aprox. 1/3 del total

#masks_test_path = dataPath+'/U-Net_images_masks/test/masks/abnormal/'
#if len(os.listdir(masks_test_path)) == 33:
#  test_masks_paths = glob.glob(masks_test_path+'*.png')
#  augmentImages(test_masks_paths, masks_test_path, 3, min_pixel_msk) 


#Normales para train: ####################

#images_train_path = dataPath+'/U-Net_images_masks/train/images/normal/'
#if len(os.listdir(images_train_path)) == 146:
#  train_images_paths = glob.glob(images_train_path+'*.png')
#  augmentImages(train_images_paths, images_train_path, 3, min_pixel_img) #(x3 aug) Si fueran 4: 78 x 4 = 312, tocaría por 3 porque la 4ta sería la original. Porque 312/2 = 156, si normal = 145 es aprox. 1/3 del total

#masks_train_path = dataPath+'/U-Net_images_masks/train/masks/normal/'
#if len(os.listdir(masks_train_path)) == 146:
#  train_masks_paths = glob.glob(masks_train_path+'*.png')
#  augmentImages(train_masks_paths, masks_train_path, 3, min_pixel_msk) 


#Normales para test:

#images_test_path = dataPath+'/U-Net_images_masks/test/images/normal/'
#if len(os.listdir(images_test_path)) == 63:
#  test_images_paths = glob.glob(images_test_path+'*.png')
#  augmentImages(test_images_paths, images_test_path, 3, min_pixel_img) #(x3 aug) Si fueran 4: 33 x 4 = 132, tocaría por 3 porque la 4ta sería la original. Porque 132/2 = 66, si normal = 62 es aprox. 1/3 del total

#masks_test_path = dataPath+'/U-Net_images_masks/test/masks/normal/'
#if len(os.listdir(masks_test_path)) == 63:
#  test_masks_paths = glob.glob(masks_test_path+'*.png')
#  augmentImages(test_masks_paths, masks_test_path, 3, min_pixel_msk)

# %% [markdown]
# Ahora mezclo normales y anormales en una carpeta ('U-Net_imgs_msks_1_class') para entrenar U-Net con máscaras normales y anormales:

# %%
if os.path.isdir(dataPath+'/U-Net_imgs_msks_1_class/') is False:
  os.makedirs(dataPath+'/U-Net_imgs_msks_1_class/train/images')
  os.makedirs(dataPath+'/U-Net_imgs_msks_1_class/train/masks')
  os.makedirs(dataPath+'/U-Net_imgs_msks_1_class/test/images')
  os.makedirs(dataPath+'/U-Net_imgs_msks_1_class/test/masks')

  abnormal_i_train_path = dataPath+'/U-Net_images_masks/train/images/abnormal/'
  abnormal_m_train_path = dataPath+'/U-Net_images_masks/train/masks/abnormal/'
  normal_i_train_path = dataPath+'/U-Net_images_masks/train/images/normal/'
  normal_m_train_path = dataPath+'/U-Net_images_masks/train/masks/normal/'

  abnormal_i_test_path = dataPath+'/U-Net_images_masks/test/images/abnormal/'
  abnormal_m_test_path = dataPath+'/U-Net_images_masks/test/masks/abnormal/'
  normal_i_test_path = dataPath+'/U-Net_images_masks/test/images/normal/'
  normal_m_test_path = dataPath+'/U-Net_images_masks/test/masks/normal/'

  abnormal_i_train_paths = glob.glob(abnormal_i_train_path+'*.png')
  abnormal_m_train_paths = glob.glob(abnormal_m_train_path+'*.png')
  normal_i_train_paths = glob.glob(normal_i_train_path+'*.png')
  normal_m_train_paths = glob.glob(normal_m_train_path+'*.png')

  abnormal_i_test_paths = glob.glob(abnormal_i_test_path+'*.png')
  abnormal_m_test_paths = glob.glob(abnormal_m_test_path+'*.png')
  normal_i_test_paths = glob.glob(normal_i_test_path+'*.png')
  normal_m_test_paths = glob.glob(normal_m_test_path+'*.png')

  for ab_image, ab_mask in zip(abnormal_i_train_paths, abnormal_m_train_paths):
      shutil.copy(ab_image, dataPath+'/U-Net_imgs_msks_1_class/train/images')   
      shutil.copy(ab_mask, dataPath+'/U-Net_imgs_msks_1_class/train/masks')

  for n_image, n_mask in zip(normal_i_train_paths, normal_m_train_paths):
      shutil.copy(n_image, dataPath+'/U-Net_imgs_msks_1_class/train/images')   
      shutil.copy(n_mask, dataPath+'/U-Net_imgs_msks_1_class/train/masks')  

  for ab_image, ab_mask in zip(abnormal_i_test_paths, abnormal_m_test_paths):
      shutil.copy(ab_image, dataPath+'/U-Net_imgs_msks_1_class/test/images')   
      shutil.copy(ab_mask, dataPath+'/U-Net_imgs_msks_1_class/test/masks')

  for n_image, n_mask in zip(normal_i_test_paths, normal_m_test_paths):
      shutil.copy(n_image, dataPath+'/U-Net_imgs_msks_1_class/test/images')   
      shutil.copy(n_mask, dataPath+'/U-Net_imgs_msks_1_class/test/masks')

# %% [markdown]
# Creo los arreglos de imágenes redimensionadas que van a ir a U-Net:

# %%
imgs_train_path = dataPath+'/U-Net_imgs_msks_1_class/train/images/'
msks_train_path = dataPath+'/U-Net_imgs_msks_1_class/train/masks/'
imgs_test_path = dataPath+'/U-Net_imgs_msks_1_class/test/images/'
msks_test_path = dataPath+'/U-Net_imgs_msks_1_class/test/masks/'

# obtenemos una lista con los archivos dentro de cada carpeta
imgs_train = glob.glob(imgs_train_path+'*.png')
msks_train = glob.glob(msks_train_path+'*.png')
imgs_test = glob.glob(imgs_test_path+'*.png')
msks_test = glob.glob(msks_test_path+'*.png')

# Listas para guardar cada elemento del dataset:
Xtrain = [] 
Ytrain = []
Xtest = []
Ytest = []

#Listas para guardar nombres correspondientes:
Xtrain_names = []
Ytrain_names = []
Xtest_names = []
Ytest_names = []

width_shape, height_shape = 128, 128 #Tamaño imágenes de entrada
dim = (width_shape, height_shape)

# Recorremos la carpeta train
for image, msk in tqdm(zip(imgs_train, msks_train)):
    img = cv2.imread(image, 1)  
    #img = resize(img, (height_shape, width_shape), mode='constant', preserve_range=True)
    img = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
    # Agrego cada imagen a la lista Xtrain:
    Xtrain.append(img)
    # Agrego cada nombre a la lista Xtrain_names:
    basename = os.path.basename(image)  # e.g. MyPhoto.jpg
    name = os.path.splitext(basename)[0]  # e.g. MyPhoto 
    Xtrain_names.append(name)
    # Leo cada una de las mascaras binarias y las redimensiono:
    mask = cv2.imread(msk, 0) 
    #mask = resize(mask, (height_shape, width_shape), mode='constant', preserve_range=True)
    mask = cv2.resize(mask, dim, interpolation = cv2.INTER_AREA)
    mask = np.expand_dims(mask, axis=-1)  
    # Agrego cada máscara a la lista Ytrain:
    Ytrain.append(mask)
    # Agrego cada nombre a la lista Xtrain_names:
    basename = os.path.basename(msk)  # e.g. MyPhoto.jpg
    name = os.path.splitext(basename)[0]  # e.g. MyPhoto 
    Ytrain_names.append(name)

# Recorremos la carpeta test
for image, msk in tqdm(zip(imgs_test, msks_test)):
    img = cv2.imread(image, 1)   
    #img = resize(img, (height_shape, width_shape), mode='constant', preserve_range=True)
    img = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
    # Agrego cada imagen a la lista Xtest:
    Xtest.append(img)
    # Agrego cada nombre a la lista Xtrain_names:
    basename = os.path.basename(image)  # e.g. MyPhoto.jpg
    name = os.path.splitext(basename)[0]  # e.g. MyPhoto 
    Xtest_names.append(name)
    # Leo cada una de las mascaras binarias y las redimensiono:
    mask = cv2.imread(msk, 0) 
    #mask = resize(mask, (height_shape, width_shape), mode='constant', preserve_range=True)
    mask = cv2.resize(mask, dim, interpolation = cv2.INTER_AREA)
    mask = np.expand_dims(mask, axis=-1)  
    # Agrego cada máscara a la lista Ytest
    Ytest.append(mask)
    # Agrego cada nombre a la lista Xtrain_names:
    basename = os.path.basename(msk)  # e.g. MyPhoto.jpg
    name = os.path.splitext(basename)[0]  # e.g. MyPhoto 
    Ytest_names.append(name)

    
X_train = np.asarray(Xtrain,dtype=np.uint8)
print('\nXtrain:',X_train.shape)

Y_train = np.asarray(Ytrain,dtype=bool)
print('Ytrain:',Y_train.shape)

X_test = np.asarray(Xtest,dtype=np.uint8)
print('Xtest:',X_test.shape)

Y_test = np.asarray(Ytest,dtype=bool)
print('Ytest:',Y_test.shape)
# Out:
# 450it [00:16, 27.48it/s]
# 96it [00:02, 35.88it/s]
# Xtrain: (450, 128, 128, 3)
# Ytrain: (450, 128, 128, 1)
# Xtest: (96, 128, 128, 3)
# Ytest: (96, 128, 128, 1)

# %%
index_img = 1
# Imagen y su mascara asociada:
print(Xtrain_names[index_img])
plt.imshow(X_train[index_img])
plt.show()
#plt.imshow(Y_train[0][:,:,0], cmap='gray')
print(Ytrain_names[index_img])
plt.imshow(np.squeeze(Y_train[index_img]), cmap='gray')
plt.show()

print(X_train[index_img].shape)
print(X_train[index_img][:,:,1].shape)
print(Y_train[index_img].shape)
print(np.squeeze(Y_train[index_img]).shape)
# Out:
# mdb107_proc
# mdb107_proc_mask
# (128, 128, 3)
# (128, 128)
# (128, 128, 1)
# (128, 128)

# %% [markdown]
# ## Modelo U-Net:

# %%
# Entrada al modelo:
Image_input = Input((height_shape, width_shape, 3))
Image_in = Lambda(lambda x: x / 255)(Image_input)

#contracting path
conv1 = Conv2D(64, (3, 3), activation='relu', padding='same')(Image_in)
conv1 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv1)
maxp1 = MaxPooling2D((2, 2))(conv1)

conv2 = Conv2D(128, (3, 3), activation='relu', padding='same')(maxp1)
conv2 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv2)
maxp2 = MaxPooling2D((2, 2))(conv2)
 
conv3 = Conv2D(256, (3, 3), activation='relu', padding='same')(maxp2)
conv3 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv3)
maxp3 = MaxPooling2D((2, 2))(conv3)
 
conv4 = Conv2D(512, (3, 3), activation='relu', padding='same')(maxp3)
conv4 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv4)
maxp4 = MaxPooling2D(pool_size=(2, 2))(conv4)
 
conv5 = Conv2D(1024, (3, 3), activation='relu', padding='same')(maxp4)
conv5 = Conv2D(1024, (3, 3), activation='relu', padding='same')(conv5)

#expansive path
up6 = Conv2DTranspose(512, (2, 2), strides=(2, 2), padding='same')(conv5)
up6 = concatenate([up6, conv4])
conv6 = Conv2D(512, (3, 3), activation='relu', padding='same')(up6)
conv6 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv6)
 
up7 = Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv6)
up7 = concatenate([up7, conv3])
conv7 = Conv2D(256, (3, 3), activation='relu', padding='same')(up7)
conv7 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv7)
 
up8 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv7)
up8 = concatenate([up8, conv2])
conv8 = Conv2D(128, (3, 3), activation='relu', padding='same')(up8)
conv8 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv8)
 
up9 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv8)
up9 = concatenate([up9, conv1], axis=3)
conv9 = Conv2D(64, (3, 3), activation='relu', padding='same')(up9)
conv9 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv9)
 
outputs = Conv2D(1, (1, 1), activation='sigmoid')(conv9)
 
model = Model(inputs=[Image_input], outputs=[outputs])

#model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
from tensorflow.keras.optimizers import Adam
model.compile(optimizer=Adam(learning_rate=0.0001), loss='binary_crossentropy', metrics=['accuracy'])


#learning_rate = 0.01
#from tensorflow.keras.optimizers import SGD
#sgd = SGD(lr=learning_rate, nesterov=True) #decay=learning_rate, #momentum=0.3, nesterov=True)
#model.compile(loss='binary_crossentropy', optimizer=sgd, metrics=['accuracy'])

#model.summary()

# %% [markdown]
# ## Tensorboard:

# %%
from tensorflow.keras.callbacks import TensorBoard

# Cargamos la extensión, definimos la carpeta logs para guardar los datos de entrenamiento, y definimos el callback
# %load_ext tensorboard
logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_callback = TensorBoard(logdir, histogram_freq=1)

# %% [markdown]
# ## Entrenamiento:

# %%
#batch_size = 39 #39 para que sean 8 pasos por epoch porque son 312 imágenes de train = 312/39 = 8
batch_size = 55 #55 para que sean 8 pasos por epoch porque son 220 imágenes de train = 220/55 = 20
epochs = 100 #60 

checkpoint_filepath = dataPath+'/tmp/checkpoints'

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_loss',
    mode='min',
    save_best_only=True)

model.fit(X_train, Y_train, validation_split=0.1, batch_size=batch_size, epochs=epochs, callbacks=[tensorboard_callback, model_checkpoint_callback])

# The model weights (that are considered the best) are loaded into the model.
model.load_weights(checkpoint_filepath)
# Out:
# Epoch 1/100
# 8/8 [==============================] - 43s 3s/step - loss: 0.6758 - accuracy: 0.9856 - val_loss: 0.6566 - val_accuracy: 1.0000
# Epoch 2/100
# 8/8 [==============================] - 14s 2s/step - loss: 0.6167 - accuracy: 0.9904 - val_loss: 0.4889 - val_accuracy: 1.0000
# Epoch 3/100
# 8/8 [==============================] - 15s 2s/step - loss: 0.3316 - accuracy: 0.9904 - val_loss: 0.1540 - val_accuracy: 1.0000
# Epoch 4/100
# 8/8 [==============================] - 12s 2s/step - loss: 0.2236 - accuracy: 0.9904 - val_loss: 0.0389 - val_accuracy: 1.0000
# Epoch 5/100
# 8/8 [==============================] - 11s 2s/step - loss: 0.1483 - accuracy: 0.9904 - val_loss: 0.0395 - val_accuracy: 1.0000
# Epoch 6/100
# 8/8 [==============================] - 11s 2s/step - loss: 0.0845 - accuracy: 0.9904 - val_loss: 0.0200 - val_accuracy: 1.0000
# Epoch 7/100
# 8/8 [==============================] - 11s 2s/step - loss: 0.0530 - accuracy: 0.9904 - val_loss: 0.0181 - val_accuracy: 1.0000
# Epoch 8/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0493 - accuracy: 0.9904 - val_loss: 0.0198 - val_accuracy: 1.0000
# Epoch 9/100
# 8/8 [==============================] - 12s 2s/step - loss: 0.0480 - accuracy: 0.9904 - val_loss: 0.0131 - val_accuracy: 1.0000
# Epoch 10/100
# 8/8 [==============================] - 12s 2s/step - loss: 0.0458 - accuracy: 0.9904 - val_loss: 0.0054 - val_accuracy: 1.0000
# Epoch 11/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0436 - accuracy: 0.9904 - val_loss: 0.0076 - val_accuracy: 1.0000
# Epoch 12/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0436 - accuracy: 0.9904 - val_loss: 0.0120 - val_accuracy: 1.0000
# Epoch 13/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0429 - accuracy: 0.9904 - val_loss: 0.0082 - val_accuracy: 1.0000
# Epoch 14/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0422 - accuracy: 0.9904 - val_loss: 0.0066 - val_accuracy: 1.0000
# Epoch 15/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.0421 - accuracy: 0.9904 - val_loss: 0.0057 - val_accuracy: 1.0000
# Epoch 16/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.0417 - accuracy: 0.9904 - val_loss: 0.0088 - val_accuracy: 1.0000
# Epoch 17/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0413 - accuracy: 0.9904 - val_loss: 0.0102 - val_accuracy: 1.0000
# Epoch 18/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.0406 - accuracy: 0.9904 - val_loss: 0.0081 - val_accuracy: 1.0000
# Epoch 19/100
# 8/8 [==============================] - 11s 1s/step - loss: 0.0403 - accuracy: 0.9904 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 20/100
# 8/8 [==============================] - 11s 1s/step - loss: 0.0415 - accuracy: 0.9904 - val_loss: 0.0108 - val_accuracy: 1.0000
# Epoch 21/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0424 - accuracy: 0.9904 - val_loss: 0.0072 - val_accuracy: 1.0000
# Epoch 22/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.0399 - accuracy: 0.9904 - val_loss: 0.0088 - val_accuracy: 1.0000
# Epoch 23/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0395 - accuracy: 0.9904 - val_loss: 0.0124 - val_accuracy: 1.0000
# Epoch 24/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0401 - accuracy: 0.9904 - val_loss: 0.0079 - val_accuracy: 1.0000
# Epoch 25/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0389 - accuracy: 0.9904 - val_loss: 0.0049 - val_accuracy: 1.0000
# Epoch 26/100
# 8/8 [==============================] - 11s 1s/step - loss: 0.0387 - accuracy: 0.9904 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 27/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0390 - accuracy: 0.9904 - val_loss: 0.0116 - val_accuracy: 1.0000
# Epoch 28/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0390 - accuracy: 0.9904 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 29/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.0374 - accuracy: 0.9904 - val_loss: 0.0048 - val_accuracy: 1.0000
# Epoch 30/100
# 8/8 [==============================] - 11s 1s/step - loss: 0.0367 - accuracy: 0.9904 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 31/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0372 - accuracy: 0.9904 - val_loss: 0.0060 - val_accuracy: 1.0000
# Epoch 32/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0366 - accuracy: 0.9904 - val_loss: 0.0053 - val_accuracy: 1.0000
# Epoch 33/100
# 8/8 [==============================] - 11s 2s/step - loss: 0.0366 - accuracy: 0.9904 - val_loss: 8.5670e-04 - val_accuracy: 1.0000
# Epoch 34/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0391 - accuracy: 0.9904 - val_loss: 0.0096 - val_accuracy: 1.0000
# Epoch 35/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0362 - accuracy: 0.9904 - val_loss: 0.0113 - val_accuracy: 1.0000
# Epoch 36/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0359 - accuracy: 0.9904 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 37/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0361 - accuracy: 0.9904 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 38/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0354 - accuracy: 0.9904 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 39/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.0340 - accuracy: 0.9904 - val_loss: 0.0043 - val_accuracy: 1.0000
# Epoch 40/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0327 - accuracy: 0.9904 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 41/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.0319 - accuracy: 0.9904 - val_loss: 0.0070 - val_accuracy: 1.0000
# Epoch 42/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.0316 - accuracy: 0.9904 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 43/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0311 - accuracy: 0.9904 - val_loss: 0.0094 - val_accuracy: 1.0000
# Epoch 44/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.0311 - accuracy: 0.9904 - val_loss: 0.0040 - val_accuracy: 1.0000
# Epoch 45/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0312 - accuracy: 0.9904 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 46/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0300 - accuracy: 0.9904 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 47/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.0296 - accuracy: 0.9904 - val_loss: 0.0056 - val_accuracy: 1.0000
# Epoch 48/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0292 - accuracy: 0.9904 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 49/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0305 - accuracy: 0.9904 - val_loss: 0.0119 - val_accuracy: 1.0000
# Epoch 50/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0299 - accuracy: 0.9904 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 51/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0287 - accuracy: 0.9904 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 52/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0295 - accuracy: 0.9904 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 53/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0289 - accuracy: 0.9904 - val_loss: 0.0102 - val_accuracy: 1.0000
# Epoch 54/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0298 - accuracy: 0.9904 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 55/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0277 - accuracy: 0.9904 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 56/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0270 - accuracy: 0.9904 - val_loss: 0.0053 - val_accuracy: 1.0000
# Epoch 57/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0262 - accuracy: 0.9904 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 58/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0257 - accuracy: 0.9904 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 59/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.0254 - accuracy: 0.9904 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 60/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.0252 - accuracy: 0.9904 - val_loss: 0.0055 - val_accuracy: 1.0000
# Epoch 61/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.0273 - accuracy: 0.9904 - val_loss: 0.0078 - val_accuracy: 1.0000
# Epoch 62/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0244 - accuracy: 0.9904 - val_loss: 0.0039 - val_accuracy: 1.0000
# Epoch 63/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.0236 - accuracy: 0.9904 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 64/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0231 - accuracy: 0.9904 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 65/100
# 8/8 [==============================] - 9s 1s/step - loss: 0.0229 - accuracy: 0.9904 - val_loss: 0.0067 - val_accuracy: 1.0000
# Epoch 66/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0228 - accuracy: 0.9904 - val_loss: 0.0044 - val_accuracy: 1.0000
# Epoch 67/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0226 - accuracy: 0.9904 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 68/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0217 - accuracy: 0.9904 - val_loss: 0.0044 - val_accuracy: 1.0000
# Epoch 69/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0224 - accuracy: 0.9910 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 70/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0231 - accuracy: 0.9917 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 71/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0217 - accuracy: 0.9922 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 72/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0227 - accuracy: 0.9925 - val_loss: 0.0058 - val_accuracy: 0.9997
# Epoch 73/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0210 - accuracy: 0.9929 - val_loss: 0.0039 - val_accuracy: 0.9998
# Epoch 74/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0188 - accuracy: 0.9933 - val_loss: 0.0045 - val_accuracy: 0.9992
# Epoch 75/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0189 - accuracy: 0.9935 - val_loss: 0.0029 - val_accuracy: 0.9996
# Epoch 76/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0176 - accuracy: 0.9940 - val_loss: 0.0022 - val_accuracy: 0.9996
# Epoch 77/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0171 - accuracy: 0.9941 - val_loss: 0.0020 - val_accuracy: 0.9996
# Epoch 78/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0153 - accuracy: 0.9946 - val_loss: 0.0033 - val_accuracy: 0.9993
# Epoch 79/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0153 - accuracy: 0.9949 - val_loss: 0.0041 - val_accuracy: 0.9989
# Epoch 80/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0161 - accuracy: 0.9942 - val_loss: 0.0031 - val_accuracy: 0.9993
# Epoch 81/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0148 - accuracy: 0.9948 - val_loss: 0.0051 - val_accuracy: 0.9988
# Epoch 82/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0137 - accuracy: 0.9950 - val_loss: 0.0050 - val_accuracy: 0.9987
# Epoch 83/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0136 - accuracy: 0.9952 - val_loss: 0.0077 - val_accuracy: 0.9973
# Epoch 84/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0151 - accuracy: 0.9947 - val_loss: 0.0026 - val_accuracy: 0.9996
# Epoch 85/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0131 - accuracy: 0.9953 - val_loss: 0.0031 - val_accuracy: 0.9990
# Epoch 86/100
# 8/8 [==============================] - 11s 2s/step - loss: 0.0118 - accuracy: 0.9957 - val_loss: 7.8588e-04 - val_accuracy: 0.9998
# Epoch 87/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0128 - accuracy: 0.9953 - val_loss: 0.0081 - val_accuracy: 0.9976
# Epoch 88/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0131 - accuracy: 0.9953 - val_loss: 0.0064 - val_accuracy: 0.9982
# Epoch 89/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0127 - accuracy: 0.9955 - val_loss: 0.0018 - val_accuracy: 0.9995
# Epoch 90/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0111 - accuracy: 0.9959 - val_loss: 0.0021 - val_accuracy: 0.9995
# Epoch 91/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0093 - accuracy: 0.9965 - val_loss: 0.0041 - val_accuracy: 0.9988
# Epoch 92/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0088 - accuracy: 0.9967 - val_loss: 0.0041 - val_accuracy: 0.9988
# Epoch 93/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0087 - accuracy: 0.9968 - val_loss: 0.0025 - val_accuracy: 0.9993
# Epoch 94/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0085 - accuracy: 0.9967 - val_loss: 8.5802e-04 - val_accuracy: 0.9998
# Epoch 95/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0088 - accuracy: 0.9967 - val_loss: 0.0019 - val_accuracy: 0.9995
# Epoch 96/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0080 - accuracy: 0.9969 - val_loss: 0.0033 - val_accuracy: 0.9989
# Epoch 97/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0082 - accuracy: 0.9969 - val_loss: 0.0047 - val_accuracy: 0.9984
# Epoch 98/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0079 - accuracy: 0.9970 - val_loss: 0.0017 - val_accuracy: 0.9995
# Epoch 99/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0071 - accuracy: 0.9973 - val_loss: 0.0025 - val_accuracy: 0.9991
# Epoch 100/100
# 8/8 [==============================] - 10s 1s/step - loss: 0.0065 - accuracy: 0.9975 - val_loss: 0.0057 - val_accuracy: 0.9980

# %% [markdown]
# Guardo el modelo:

# %%
model.save('U-Net_min_val_loss.h5')  # creates a HDF5 file 'my_model.h5'

del model  # deletes the existing model

# returns a compiled model, identical to the previous one
from keras.models import load_model
model = load_model('U-Net_min_val_loss.h5')

#print(model.summary())

# %%
from keras.callbacks import History
#epochs = 5

# list all data in history
print(history_U_Net.history.keys())
#print(history.history['accuracy'])

# summarize history for accuracy
plt.figure(figsize=(12, 6))
plt.plot(np.arange(1, epochs+1, 1), history_U_Net.history['accuracy'])
plt.plot(np.arange(1, epochs+1, 1), history_U_Net.history['val_accuracy'])
#plt.xticks(np.arange(1, epochs+1, 1), list(range(1, epochs+1)))
plt.xlim([0, epochs+1])
plt.title('U-Net accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left', framealpha=1)
plt.grid()
plt.show()

# summarize history for loss
plt.figure(figsize=(12, 6))
plt.plot(np.arange(1, epochs+1, 1), history_U_Net.history['loss'])
plt.plot(np.arange(1, epochs+1, 1), history_U_Net.history['val_loss'])
#plt.xticks(np.arange(1, epochs+1, 1), list(range(1, epochs+1)))
plt.xlim([0, epochs+1])
plt.title('U-Net loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right', framealpha=1)#, fancybox=True)
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-1f9493ffc6c0> in <module>
#       3
#       4 # list all data in history
# ----> 5 print(history_U_Net.history.keys())
#       6 #print(history.history['accuracy'])
#       7
#
# NameError: name 'history_U_Net' is not defined

# %% [markdown]
# ## Prueba con imagen de test:

# %%
image_position = 2   #Tener en cuenta la 14 del arreglo de las que tienen anormalidad, la 1 también, la 12 también (revisar 13) #33

print('Mamografía:')
print(Xtest_names[image_position])
plt.imshow(X_test[image_position], cmap='gray')
plt.show()

print('\nMáscara ground truth:')
print(Ytest_names[image_position])
test_masks = Y_test
plt.imshow(np.squeeze(test_masks[image_position]), cmap='gray')
plt.show()

print('\nMáscara detectada:')
preds = model.predict(X_test)
plt.imshow(np.squeeze(preds[image_position]), cmap='gray')
plt.show()



#Pruebas faltantes:
#Probar con 10% para valid y 10% para test
#Probar entrenar con segmentadas U-Net
# Out:
# Mamografía:
# mdb010_proc
# Máscara ground truth:
# mdb010_proc_mask
# Máscara detectada:
# 3/3 [==============================] - 0s 160ms/step

# %%
# Test de una imagen cualquiera indicando la ruta:

#image_path = dataPath+'/allmias_PNG_mat_eq/mdb226_output.png' 
#mask_path = dataPath+'/U-Net_imgs_msks_1_class/train/masks/mdb226_proc_mask.png'

#image_path = dataPath+'/U-Net_imgs_msks_1_class/test/images/mdb005_proc.png' 
#mask_path = dataPath+'/U-Net_imgs_msks_1_class/test/masks/mdb005_proc_mask.png'

#image_path = dataPath+'/U-Net_images_masks/test/images/normal/mdb260_proc.png' #mdb024
#mask_path = dataPath+'/U-Net_images_masks/test/masks/normal/mdb260_proc_mask.png'

image_path = dataPath+'/U-Net_imgs_msks_1_class/train/images/mdb226_proc.png' 
mask_path = dataPath+'/U-Net_imgs_msks_1_class/train/masks/mdb226_proc_mask.png'

image = cv2.imread(image_path)
#image_0 = resize(image, (height_shape, width_shape), mode='constant')
#image = resize(image, (height_shape, width_shape), mode='constant', preserve_range=True)
image = cv2.resize(image, dim, interpolation = cv2.INTER_AREA)


mask = cv2.imread(mask_path)
#mask = resize(mask, (height_shape, width_shape), mode='constant', preserve_range=True)
mask = cv2.resize(mask, dim, interpolation = cv2.INTER_AREA)

print('Mamografía:')
print(image_path[45:])
#print(image_path[47:])
plt.imshow(image, cmap='gray')
plt.show()

print('\nGround truth mask:')
print(mask_path[44:])
#print(mask_path[46:])
plt.imshow(mask, cmap='gray')
plt.show()

image = np.expand_dims(image, axis=0)
pred = model.predict(image)
print('\nPredicted mask:')
plt.imshow(np.squeeze(pred), cmap='gray')
plt.show()
'''
print('\nBlended image:')
blend_img = cv2.addWeighted(image_0, 1, mask, 0.2, 0)
plt.imshow(np.squeeze(blend_img), cmap='gray')
plt.show()
'''
# Out:
# Mamografía:
# /mdb226_proc.png
# Ground truth mask:
# /mdb226_proc_mask.png
# 1/1 [==============================] - 0s 29ms/step
#
# Predicted mask:
# "\nprint('\nBlended image:')\nblend_img = cv2.addWeighted(image_0, 1, mask, 0.2, 0)\nplt.imshow(np.squeeze(blend_img), cmap='gray')\nplt.show()\n"

# %% [markdown]
# ## Gráficas de entrenamiento:

# %%
# %reload_ext tensorboard
# %tensorboard --logdir logs --host localhost
